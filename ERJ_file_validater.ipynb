# %%
import geopandas as gp
import pandas as pd
import os
import re

# %%
level_race_name_dict = {"CONG_DIST":"CON",
    "SLDL_DIST":"SL",
    "SLDU_DIST":"SU"}

# %%
def district_assignment_errors(election_results_df, level):
    '''
    This function will check whether the votes in a precinct match the district assignment
    Note: As written, this will only work for fully numeric district assignments
    '''
    
    # This boolean is used to help clean up the print statements
    any_error = False
    # Convert from the name of the district assignment column, to how it is referred to in column names
    finding = level_race_name_dict[level]
    # Iterate over the dataframe row-by-row
    for index,row in election_results_df.iterrows():
        # Get the district assignment for that row
        district_assignment = row[level]
        # Iterate over every row column by column
        for val in row.index:
            # If the name for the type of district is in the column name and there are non-zero votes
            if finding in val and row[val] != 0 and val!= level and val not in ["SLDU_DIST","SLDL_DIST","CONG_DIST"]:
                # Grab the numbers for district assignments
                regex_string = finding+'\d*'
                # The len(finding) part is needed here as sometimes there is more than one digit to the district
                col_district = re.findall(regex_string, val)[0][len(finding):]
                # Makes sure that "CON", "SL", or "SU" wasn't found in a name (more than 5 characters into the col name)
                if (val.find(finding) < 5):
                    # If the district number in the column name doesn't equal the district name in the assignment column
                    if (col_district != district_assignment):
                        print(val.find(finding))
                        print(re.findall(regex_string, val))
                        if not(any_error):
                            print("***ERROR SPOTTED***")
                        print("District Assignment: ", district_assignment)
                        print("Value" , col_district)
                        print("Column", val)
                        print("Number of votes", row[val])
                        print(row["UNIQUE_ID"])
                        print(" ")
                        any_error = True
    return any_error

# %%
def run_validation(election_results_df):
    '''
    This code validates a handful of things in a given ERJ file:
    1) Whether the values in the "UNIQUE_ID" column are indeed unique
    2) That there is a "COUNTYFP" column
    3) That "UNIQUE_ID" and "COUNTYFP" are in the right order within the columns
    4) That the actual votes assigned in cases of districts match the stated district assignments.
        In other words, if we say a precinct is in CONG_DIST 4, does it only receive votes in CONG_DIST 4
        This function calls the "district_assignment_errors" function above to perform this check
    '''
    
    # Confirm that UNIQUE_ID column is unique
    assert(max(election_results_df["UNIQUE_ID"].value_counts(dropna=False)) == 1), "Non-unique UNIQUE_ID"
    print("CONFIRMED: UNIQUE_ID is unique")
    
    # Confirm that COUNTYFP column has been added
    assert('COUNTYFP' in list(election_results_df.columns)), "No 'COUNTYFP' column"
    print("CONFIRMED: COUNTYFP column added")
    
    #Check order of columns
    assert((list(election_results_df.columns)[0]=="UNIQUE_ID") and (list(election_results_df.columns)[1]=="COUNTYFP")), "Incorrect column placement"
    print("CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position")
    
    # Confirm that stated district assignment, matches actual district assignment
    contains_cong_assignment = "CONG_DIST" in list(election_results_df.columns) or "CON_DIST" in list(election_results_df.columns)
    if(contains_cong_assignment):
        assert(not(district_assignment_errors(election_results_df, "CONG_DIST"))), "Bad CONG_DIST assignment"
        print("CONFIRMED: Actual congressional votes match CONG_DIST assignment")
        
    contains_sldu_assignment = "SLDU_DIST" in list(election_results_df.columns)
    if(contains_sldu_assignment):
        assert(not(district_assignment_errors(election_results_df, "SLDU_DIST"))), "Bad SLDU_DIST assignment"
        print("CONFIRMED: Actual su votes match SLDU_DIST assignment")
        
    contains_sldl_assignment = "SLDL_DIST" in list(election_results_df.columns)
    if(contains_sldl_assignment):
        assert(not(district_assignment_errors(election_results_df, "SLDL_DIST"))), "Bad SLDL_DIST assignment"
        print("CONFIRMED: Actual sl votes match SLDL_DIST assignment")

# %%
def validate_file(file_name):
    '''
    This is the function that will call the other needed functions
    
    file_name : Should be a string, something like "az_gen_20_prec"
    '''
    files = os.listdir("./"+file_name+"/")
    
    # Iterate over the files within that filepath
    for val in files:
        if ".shp" in val:
            print("Running check on:", val)
            file_load = gp.read_file("./"+file_name+"/"+val)
            run_validation(file_load)
            print("")

# %%
# Fill this in with your file name
file_name = ""

# Run the below to call the validation
validate_file(file_name)

# Example Call
# file_name = "az_gen_20_prec"
# validate_file(file_name)
# Out:
# Running check on: az_gen_20_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
# CONFIRMED: Actual su votes match SLDU_DIST assignment
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: az_prim_20_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
# CONFIRMED: Actual su votes match SLDU_DIST assignment
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: fl_gen_20_sldu_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual su votes match SLDU_DIST assignment
#
# Running check on: fl_gen_20_sldl_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: fl_gen_20_st_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
#
# Running check on: fl_gen_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
#
# Running check on: nc_gen_20_sldl_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: nc_gen_20_st_sldu_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual su votes match SLDU_DIST assignment
#
# Running check on: nc_gen_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
#
# Running check on: oh_gen_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
#
# Running check on: oh_gen_20_st_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
#
# Running check on: oh_gen_20_sldl_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: oh_gen_20_sldu_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual su votes match SLDU_DIST assignment
#
# Running check on: oh_prim_20_st_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
#
# Running check on: oh_prim_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
#
# Running check on: oh_prim_20_sldl_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: oh_prim_20_sldu_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual su votes match SLDU_DIST assignment
#
# Running check on: ms_gen_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
#
# Running check on: ms_gen_20_st_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# 1
# ['SL087']
# ***ERROR SPOTTED***
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 378
# 28073000009
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 229
# 28073000009
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 334
# 28073000009
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 177
# 28073000014
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 70
# 28073000014
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 224
# 28073000014
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 451
# 28073000010
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 235
# 28073000010
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 407
# 28073000010
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 489
# 28073000012
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 205
# 28073000012
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 839
# 28073000012
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 45
# 28073000017
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 19
# 28073000017
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 80
# 28073000017
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 240
# 28073000011
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 106
# 28073000011
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 143
# 28073000011
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 72
# 28073000016
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 43
# 28073000016
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 109
# 28073000016
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 358
# 28073000008
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 157
# 28073000008
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 353
# 28073000008
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 112
# 28073000023
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 20
# 28073000023
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 118
# 28073000023
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 199
# 28073000013
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 55
# 28073000013
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 180
# 28073000013
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 1
# 28073000007
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 171
# 28035000109
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 81
# 28035000109
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 240
# 28035000109
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 237
# 28035000101
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 128
# 28035000101
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 306
# 28035000101
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 361
# 28035000107
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 155
# 28035000107
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 502
# 28035000107
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 229
# 28035000502
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 117
# 28035000502
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 340
# 28035000502
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NCON
# Number of votes 46
# 28035000110
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NMOR
# Number of votes 27
# 28035000110
#
# 1
# ['SL087']
# District Assignment:  87
# Value 087
# Column GSL087NTUB
# Number of votes 64
# 28035000110
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-99-1146f7873f6c> in <module>
#       1 for file in file_name_list:
# ----> 2     validate_file(file)
#
# <ipython-input-97-8fd48bc3295f> in validate_file(file_name)
#       7             if "CON_DIST" in file_load.columns:
#       8                 file_load.rename(columns={"CON_DIST":"CONG_DIST"}, inplace=True)
# ----> 9             run_validation(file_load)
#      10             print("")
#
# <ipython-input-96-f8b450abaa16> in run_validation(election_results_df)
#      26     contains_sldl_assignment = "SLDL_DIST" in list(election_results_df.columns)
#      27     if(contains_sldl_assignment):
# ---> 28         assert(not(district_assignment_errors(election_results_df, "SLDL_DIST"))), "Bad SLDL_DIST assignment"
#      29         print("CONFIRMED: Actual sl votes match SLDL_DIST assignment")
#      30
#
# AssertionError: Bad SLDL_DIST assignment
